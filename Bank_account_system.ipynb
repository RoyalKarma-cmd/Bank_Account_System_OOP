# %%
class BankAccount:

    def __init__(self, account_holder, balance):
        self.account_holder = account_holder
        self.__balance = balance

    def deposit(self, amount):
        if amount > 0:
            self.__balance += amount
            print(f"₹{amount}/- has been deposited ")

        else:
            print("Invalid deposit amount")

    def withdraw(self, amount):

        if amount <= self.__balance:
            self.__balance -= amount
            print(f"₹{amount}/- has been Widthdrawed successfully")
        else:
            print("\nInsuffucient Balance")

    def show_balance(self):
        print(f"Current Balance is:",self.__balance)

    def show_details(self):

        print("~~~~~~~~~~Account Details~~~~~~~~~~~")

        print("Account Holder:",self.account_holder)
        print("Balance:",self.__balance)

        print("___________________________________")


account = BankAccount("Jaydeep", 10000)

account.show_details()

account.deposit(2500)

account.show_balance()

account.withdraw(500)

account.show_balance()
# Out:
# ~~~~~~~~~~Account Details~~~~~~~~~~~
# Account Holder: Jaydeep
# Balance: 10000
# ___________________________________
# ₹2500/- has been deposited
# Current Balance is: 12500
# ₹500/- has been Widthdrawed successfully
# Current Balance is: 12000
